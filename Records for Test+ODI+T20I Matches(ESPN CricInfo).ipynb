# %%
import pandas as pd

# %%
url = "https://www.espncricinfo.com/records/most-runs-in-career-284269"

# %%
all_tables = pd.read_html(url)

# %%
print(len(all_tables))
# Out:
# 1

# %%
df=all_tables[0]

# %%
df
# Out:
#                          Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0            SR Tendulkar (IND)  1989-2013  664   782  74  34357  248*  48.52
# 1   KC Sangakkara (Asia/ICC/SL)  2000-2015  594   666  67  28016   319  46.77
# 2          RT Ponting (AUS/ICC)  1995-2012  560   668  70  27483   257  45.95
# 3                 V Kohli (IND)  2008-2024  522   580  86  26733  254*  54.11
# 4    DPMD Jayawardene (Asia/SL)  1997-2015  652   725  62  25957   374  39.15
# ..                          ...        ...  ...   ...  ..    ...   ...    ...
# 88         ME Trescothick (ENG)  2000-2006  202   268  16  10326   219  40.97
# 89              G Gambhir (IND)  2003-2016  242   283  18  10324   206  38.95
# 90                MD Crowe (NZ)  1982-1995  220   271  29  10148   299  41.93
# 91              TWM Latham (NZ)  2012-2024  253   299  26  10033  264*  36.75
# 92              GW Flower (ZIM)  1992-2010  288   337  24  10028  201*  32.03
#
# ...

# %%
#Rename Multiple Columns

# %%
df = df.rename(columns = {'Mat':'Matches','Inns':'Innings','Ave':'Average','NO':'Not_Outs','HS':'Highest_Innings_Score','BF':'Balls_Faced','SR':'Strike_Rate','100':'100s','50':'50s','0s':'0s',})

# %%
df
# Out:
#                          Player       Span  Matches  Innings  Not_Outs   Runs  \
# 0            SR Tendulkar (IND)  1989-2013      664      782        74  34357
# 1   KC Sangakkara (Asia/ICC/SL)  2000-2015      594      666        67  28016
# 2          RT Ponting (AUS/ICC)  1995-2012      560      668        70  27483
# 3                 V Kohli (IND)  2008-2024      522      580        86  26733
# 4    DPMD Jayawardene (Asia/SL)  1997-2015      652      725        62  25957
# ..                          ...        ...      ...      ...       ...    ...
# 88         ME Trescothick (ENG)  2000-2006      202      268        16  10326
# 89              G Gambhir (IND)  2003-2016      242      283        18  10324
# 90                MD Crowe (NZ)  1982-1995      220      271        29  10148
# 91              TWM Latham (NZ)  2012-2024      253      299        26  10033
# 92              GW Flower (ZIM)  1992-2010      288      337        24  10028
#
# ...

# %%
#check Null Valuse

# %%
df.isnull().any()
# Out:
# Player                   False
# Span                     False
# Matches                  False
# Innings                  False
# Not_Outs                 False
# Runs                     False
# Highest_Innings_Score    False
# Average                  False
# Balls_Faced              False
# Strike_Rate              False
# 100s                     False
# 50s                      False
# 0                        False
# 4s                       False
# 6s                       False
# dtype: bool

# %%
#check Duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 88    False
# 89    False
# 90    False
# 91    False
# 92    False
# Length: 93, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches, Innings, Not_Outs, Runs, Highest_Innings_Score, Average, Balls_Faced, Strike_Rate, 100s, 50s, 0, 4s, 6s]
# Index: []

# %%
#Split up Span into Start and End Date

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1989, 2013]
# 1     [2000, 2015]
# 2     [1995, 2012]
# 3     [2008, 2024]
# 4     [1997, 2015]
#           ...
# 88    [2000, 2006]
# 89    [2003, 2016]
# 90    [1982, 1995]
# 91    [2012, 2024]
# 92    [1992, 2010]
# Name: Span, Length: 93, dtype: object

# %%
df['Span'].str.split(pat = '-').str[0]
# Out:
# 0     1989
# 1     2000
# 2     1995
# 3     2008
# 4     1997
#       ...
# 88    2000
# 89    2003
# 90    1982
# 91    2012
# 92    1992
# Name: Span, Length: 93, dtype: object

# %%
df['Start_Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                          Player       Span  Matches  Innings  Not_Outs   Runs  \
# 0            SR Tendulkar (IND)  1989-2013      664      782        74  34357
# 1   KC Sangakkara (Asia/ICC/SL)  2000-2015      594      666        67  28016
# 2          RT Ponting (AUS/ICC)  1995-2012      560      668        70  27483
# 3                 V Kohli (IND)  2008-2024      522      580        86  26733
# 4    DPMD Jayawardene (Asia/SL)  1997-2015      652      725        62  25957
# ..                          ...        ...      ...      ...       ...    ...
# 88         ME Trescothick (ENG)  2000-2006      202      268        16  10326
# 89              G Gambhir (IND)  2003-2016      242      283        18  10324
# 90                MD Crowe (NZ)  1982-1995      220      271        29  10148
# 91              TWM Latham (NZ)  2012-2024      253      299        26  10033
# 92              GW Flower (ZIM)  1992-2010      288      337        24  10028
#
# ...

# %%
#Dropping Span

# %%
df = df.drop(['Span'], axis = 1)

# %%
df
# Out:
#                          Player  Matches  Innings  Not_Outs   Runs  \
# 0            SR Tendulkar (IND)      664      782        74  34357
# 1   KC Sangakkara (Asia/ICC/SL)      594      666        67  28016
# 2          RT Ponting (AUS/ICC)      560      668        70  27483
# 3                 V Kohli (IND)      522      580        86  26733
# 4    DPMD Jayawardene (Asia/SL)      652      725        62  25957
# ..                          ...      ...      ...       ...    ...
# 88         ME Trescothick (ENG)      202      268        16  10326
# 89              G Gambhir (IND)      242      283        18  10324
# 90                MD Crowe (NZ)      220      271        29  10148
# 91              TWM Latham (NZ)      253      299        26  10033
# 92              GW Flower (ZIM)      288      337        24  10028
#
#    Highest_Innings_Score  Average Balls_Faced Strike_Rate  100s  50s   0  \
# 0                   248*    48.52      50817+      67.58*   100  164  34
# ...

# %%
#split Country from Players

# %%
df['Player'].str.split(pat = '(')
# Out:
# 0              [SR Tendulkar , IND)]
# 1     [KC Sangakkara , Asia/ICC/SL)]
# 2            [RT Ponting , AUS/ICC)]
# 3                   [V Kohli , IND)]
# 4      [DPMD Jayawardene , Asia/SL)]
#                    ...
# 88           [ME Trescothick , ENG)]
# 89                [G Gambhir , IND)]
# 90                  [MD Crowe , NZ)]
# 91                [TWM Latham , NZ)]
# 92                [GW Flower , ZIM)]
# Name: Player, Length: 93, dtype: object

# %%
df['Player'].str.split(pat = '(').str[0]
# Out:
# 0         SR Tendulkar
# 1        KC Sangakkara
# 2           RT Ponting
# 3              V Kohli
# 4     DPMD Jayawardene
#             ...
# 88      ME Trescothick
# 89           G Gambhir
# 90            MD Crowe
# 91          TWM Latham
# 92           GW Flower
# Name: Player, Length: 93, dtype: object

# %%
df['Player'].str.split(pat = '(').str[1]
# Out:
# 0             IND)
# 1     Asia/ICC/SL)
# 2         AUS/ICC)
# 3             IND)
# 4         Asia/SL)
#           ...
# 88            ENG)
# 89            IND)
# 90             NZ)
# 91             NZ)
# 92            ZIM)
# Name: Player, Length: 93, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df['Country'] = df['Country'].str.split(pat = ')').str[0]

# %%
df['Country']
# Out:
# 0             IND
# 1     Asia/ICC/SL
# 2         AUS/ICC
# 3             IND
# 4         Asia/SL
#          ...
# 88            ENG
# 89            IND
# 90             NZ
# 91             NZ
# 92            ZIM
# Name: Country, Length: 93, dtype: object

# %%
df
# Out:
#                          Player  Matches  Innings  Not_Outs   Runs  \
# 0            SR Tendulkar (IND)      664      782        74  34357
# 1   KC Sangakkara (Asia/ICC/SL)      594      666        67  28016
# 2          RT Ponting (AUS/ICC)      560      668        70  27483
# 3                 V Kohli (IND)      522      580        86  26733
# 4    DPMD Jayawardene (Asia/SL)      652      725        62  25957
# ..                          ...      ...      ...       ...    ...
# 88         ME Trescothick (ENG)      202      268        16  10326
# 89              G Gambhir (IND)      242      283        18  10324
# 90                MD Crowe (NZ)      220      271        29  10148
# 91              TWM Latham (NZ)      253      299        26  10033
# 92              GW Flower (ZIM)      288      337        24  10028
#
#    Highest_Innings_Score  Average Balls_Faced Strike_Rate  100s  50s   0  \
# 0                   248*    48.52      50817+      67.58*   100  164  34
# ...

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]

# %%
df['Player']
# Out:
# 0         SR Tendulkar
# 1        KC Sangakkara
# 2           RT Ponting
# 3              V Kohli
# 4     DPMD Jayawardene
#             ...
# 88      ME Trescothick
# 89           G Gambhir
# 90            MD Crowe
# 91          TWM Latham
# 92           GW Flower
# Name: Player, Length: 93, dtype: object

# %%
df.head()
# Out:
#               Player  Matches  Innings  Not_Outs   Runs Highest_Innings_Score  \
# 0      SR Tendulkar       664      782        74  34357                  248*
# 1     KC Sangakkara       594      666        67  28016                   319
# 2        RT Ponting       560      668        70  27483                   257
# 3           V Kohli       522      580        86  26733                  254*
# 4  DPMD Jayawardene       652      725        62  25957                   374
#
#    Average Balls_Faced Strike_Rate  100s  50s   0     4s   6s Start_Year  \
# 0    48.52      50817+      67.58*   100  164  34  4076+  264       1989
# 1    46.77       42086       66.56    63  153  28   3015  159       2000
# 2    45.95       40130       68.48    71  146  39   2781  246       1995
# 3    54.11       33643       79.46    80  139  35   2646  294       2008
# 4    39.15       40100       64.73    54  136  47   2679  170       1997
#
#   Final_Year      Country
# 0       2013          IND
# ...

# %%
#change the extra special marks

# %%
df['Highest_Innings_Score'] = df['Highest_Innings_Score'].str.split(pat = '*').str[0]

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]

# %%
df['Strike_Rate'] = df['Strike_Rate'].str.split(pat = '*').str[0]

# %%
df['4s'] = df['4s'].str.split(pat = '+').str[0]

# %%
df['6s'] = df['6s'].str.split(pat = '+').str[0]

# %%
df
# Out:
#                Player  Matches  Innings  Not_Outs   Runs  \
# 0       SR Tendulkar       664      782        74  34357
# 1      KC Sangakkara       594      666        67  28016
# 2         RT Ponting       560      668        70  27483
# 3            V Kohli       522      580        86  26733
# 4   DPMD Jayawardene       652      725        62  25957
# ..                ...      ...      ...       ...    ...
# 88    ME Trescothick       202      268        16  10326
# 89         G Gambhir       242      283        18  10324
# 90          MD Crowe       220      271        29  10148
# 91        TWM Latham       253      299        26  10033
# 92         GW Flower       288      337        24  10028
#
#    Highest_Innings_Score  Average Balls_Faced Strike_Rate  100s  50s   0  \
# 0                    248    48.52       50817       67.58   100  164  34
# 1                    319    46.77       42086       66.56    63  153  28
# ...

# %%
#Change Data Types

# %%
df.dtypes
# Out:
# Player                    object
# Matches                    int64
# Innings                    int64
# Not_Outs                   int64
# Runs                       int64
# Highest_Innings_Score     object
# Average                  float64
# Balls_Faced               object
# Strike_Rate               object
# 100s                       int64
# 50s                        int64
# 0                          int64
# 4s                        object
# 6s                        object
# Start_Year                object
# Final_Year                object
# Country                   object
# dtype: object

# %%
df['Highest_Innings_Score'] = df['Highest_Innings_Score'].astype('int')

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df['Strike_Rate'] = df['Strike_Rate'].astype('float')

# %%
df['4s'] = df['4s'].astype('int')

# %%
df['6s'] = df['6s'].astype('int')

# %%
df['Start_Year'] = df['Start_Year'].astype('int')

# %%
df['Final_Year'] = df['Final_Year'].astype('int')

# %%
df.dtypes
# Out:
# Player                    object
# Matches                    int64
# Innings                    int64
# Not_Outs                   int64
# Runs                       int64
# Highest_Innings_Score      int64
# Average                  float64
# Balls_Faced                int64
# Strike_Rate              float64
# 100s                       int64
# 50s                        int64
# 0                          int64
# 4s                         int64
# 6s                         int64
# Start_Year                 int64
# Final_Year                 int64
# Country                   object
# dtype: object

# %%
#Questuin Build out Career_Length Column
#hint convert rookie/final year and substtract

# %%
df['Career_length'] = df['Final_Year'] - df['Start_Year']

# %%
df
# Out:
#                Player  Matches  Innings  Not_Outs   Runs  \
# 0       SR Tendulkar       664      782        74  34357
# 1      KC Sangakkara       594      666        67  28016
# 2         RT Ponting       560      668        70  27483
# 3            V Kohli       522      580        86  26733
# 4   DPMD Jayawardene       652      725        62  25957
# ..                ...      ...      ...       ...    ...
# 88    ME Trescothick       202      268        16  10326
# 89         G Gambhir       242      283        18  10324
# 90          MD Crowe       220      271        29  10148
# 91        TWM Latham       253      299        26  10033
# 92         GW Flower       288      337        24  10028
#
#     Highest_Innings_Score  Average  Balls_Faced  Strike_Rate  100s  50s   0  \
# 0                     248    48.52        50817        67.58   100  164  34
# 1                     319    46.77        42086        66.56    63  153  28
# ...

# %%
# Calculattions with the dataframe

# %%
#Question 1 -> Cricketers in this DF what is the Average Career Length

# %%
df['Career_length'].mean()
# Out:
# 15.118279569892474

# %%
#Question 2 AVG Bationg_Strike_Rate for cricketers who played over 10 years

# %%
df[df['Career_length'] > 10][['Player', 'Strike_Rate']]
# Out:
#                Player  Strike_Rate
# 0       SR Tendulkar         67.58
# 1      KC Sangakkara         66.56
# 2         RT Ponting         68.48
# 3            V Kohli         79.46
# 4   DPMD Jayawardene         64.73
# ..                ...          ...
# 87         BA Stokes         70.13
# 89         G Gambhir         68.85
# 90          MD Crowe         54.36
# 91        TWM Latham         59.73
# 92         GW Flower         50.81
#
# [86 rows x 2 columns]

# %%
df[df['Career_length'] > 10]['Strike_Rate'].mean()
# Out:
# 67.30988372093023

# %%
#Question 3 find number of cricketers who played before 2000

# %%
df[df['Final_Year'] < 2000][['Player', 'Strike_Rate']]
# Out:
#             Player  Strike_Rate
# 22      AR Border         48.76
# 31  Javed Miandad         54.83
# 32      DL Haynes         53.31
# 38   IVA Richards         78.69
# 51        DC Boon         49.08
# 53    SM Gavaskar         48.25
# 54       GA Gooch         52.74
# 56   Saleem Malik         61.85
# 59   CG Greenidge         55.64
# 63  RB Richardson         54.82
# 71       DI Gower         55.65
# 78      MA Taylor         45.90
# 86  DB Vengsarkar         50.04
# 90       MD Crowe         54.36

# %%
len(df[df['Final_Year'] < 2000]['Player'])
# Out:
# 14
